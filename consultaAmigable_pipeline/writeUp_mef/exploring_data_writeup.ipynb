# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import re

# %%
def load_file_with_dynamic_header(file_path):
    # It reads raw file without headers
    raw_df = pd.read_excel(file_path, header=None)

    header_keywords = [
        "actividad/proyecto",
        "producto / proyecto",
        "pia",
        "pim"
    ]

    # This detects header row
    matches = raw_df.apply(
        lambda row: any(
            row.astype(str)
               .str.lower()
               .str.contains(k, regex=False)
               .any()
            for k in header_keywords
        ),
        axis=1
    )

    if not matches.any():
        raise ValueError(f"No header row found in {file_path}")

    header_row_idx = matches.idxmax()

    # --------------------------------------------------
    # This extracts ONLY first column for Funcion
    # --------------------------------------------------
    funcion_value = None
    funcion_pattern = re.compile(r"^funci[oó]n\s*\d+", re.IGNORECASE)

    for i in range(header_row_idx):
        cell_value = raw_df.iloc[i, 0]  # 👈 ONLY COLUMN A
        if isinstance(cell_value, str) and funcion_pattern.search(cell_value):
            funcion_value = cell_value.strip()
            break

    # Reload file using detected header
    df = pd.read_excel(file_path, skiprows=header_row_idx)

    # Add propagated column
    df["Responsabilidad funcional"] = funcion_value

    return df



def load_spending_data_for_year(base_dir, year):
    base_dir = Path(base_dir)
    year_folder = base_dir / f"SMPCT_{year}"

    if not year_folder.exists():
        raise FileNotFoundError(f"Folder not found: {year_folder}")

    dfs = []

    for file in year_folder.glob("*.xlsx"):
        filename = file.stem
        parts = filename.split("_")

        # Function from filename (technical)
        if len(parts) <= 3:
            function = "general"
        else:
            function = "_".join(parts[3:]).lower()

        try:
            df = load_file_with_dynamic_header(file)

            # Traceability fields
            df["year"] = int(year)
            #df["function"] = function
            df["source_file"] = file.name

            dfs.append(df)

        except Exception as e:
            print(f"Error reading {file.name}: {e}")

    if not dfs:
        return pd.DataFrame()

    return pd.concat(dfs, ignore_index=True)

# %%
df_2007 = load_spending_data_for_year(r"D:\cg_inter_stuff\Data_engineer\PipeLiningEverythingProjetcs\consultaAmigable_pipeline\dev\spending_data", 2007)


df_2007
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8416\2238942496.py:86: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(dfs, ignore_index=True)
#    Producto / Proyecto        PIA        PIM Certificación Compromiso Anual  \
# 0                  NaN        NaN        NaN           NaN              NaN
# 1                  NaN  1819517.0  2449205.0           NaN              NaN
# 2                  NaN   140000.0   128134.0           NaN              NaN
# 3                  NaN   594781.0  1064751.0           NaN              NaN
# 4                  NaN  1082528.0   664767.0           NaN              NaN
# 5                  NaN   250000.0   249768.0           NaN              NaN
# 6                  NaN  1086019.0  1992799.0           NaN              NaN
# 7                  NaN    50000.0   389446.0           NaN              NaN
# 8                  NaN        NaN        NaN           NaN              NaN
# 9                  NaN   187507.0   134180.0           NaN              NaN
# 10                 NaN  1385010.0  1995452.0           NaN              NaN
# 11                 NaN   247000.0   319573.0           NaN              NaN
# 12                 NaN        NaN        NaN           NaN              NaN
# 13                 NaN    80000.0   128134.0           NaN              NaN
# 14                 NaN    60000.0        0.0           NaN              NaN
# 15                 NaN        NaN        NaN           NaN              NaN
# 16                 NaN   897528.0   317226.0           NaN              NaN
# 17                 NaN    80000.0   224696.0           NaN              NaN
# 18                 NaN        0.0     4871.0           NaN              NaN
# 19                 NaN    80000.0    42750.0           NaN              NaN
# 20                 NaN    25000.0    75224.0           NaN              NaN
# 21                 NaN        NaN        NaN           NaN              NaN
# 22                 NaN     7497.0     7705.0           NaN              NaN
# 23                 NaN     1083.0     7606.0           NaN              NaN
# 24                 NaN   257598.0   257598.0           NaN              NaN
# 25                 NaN    40923.0   275983.0           NaN              NaN
# 26                 NaN   100000.0   155706.0           NaN              NaN
# 27                 NaN   100000.0   144259.0           NaN              NaN
# 28                 NaN    37680.0    36779.0           NaN              NaN
# 29                 NaN    50000.0        0.0           NaN              NaN
# 30                 NaN        0.0   179115.0           NaN              NaN
# 31                 NaN        NaN        NaN           NaN              NaN
# 32                 NaN    80000.0      972.0           NaN              NaN
# 33                 NaN        0.0   125629.0           NaN              NaN
# 34                 NaN        0.0     7073.0           NaN              NaN
# 35                 NaN   120000.0    21751.0           NaN              NaN
# 36                 NaN        0.0     6050.0           NaN              NaN
# 37                 NaN    50000.0    88293.0           NaN              NaN
# 38                 NaN        NaN        NaN           NaN              NaN
# 39                 NaN    82898.0   493957.0           NaN              NaN
# 40                 NaN   169629.0    73414.0           NaN              NaN
# 41                 NaN   419044.0   517565.0           NaN              NaN
# 42                 NaN   120460.0   295307.0           NaN              NaN
# 43                 NaN   273988.0   588903.0           NaN              NaN
# 44                 NaN    20000.0    23653.0           NaN              NaN
# 45                 NaN        NaN        NaN           NaN              NaN
# 46                 NaN    50000.0        0.0           NaN              NaN
# 47                 NaN        0.0   389446.0           NaN              NaN
#
#      Ejecución Unnamed: 6 Unnamed: 7 Avance %  \
# 0   Compromiso        NaN        NaN      NaN
# 1      2161468        NaN        NaN     88.3
# 2       128131        NaN        NaN    100.0
# 3       979015        NaN        NaN     91.9
# 4       609944        NaN        NaN     91.8
# 5       201549        NaN        NaN     80.7
# 6      1630006        NaN        NaN     81.8
# 7       303780        NaN        NaN     78.0
# 8   Compromiso        NaN        NaN      NaN
# 9       134179        NaN        NaN    100.0
# 10     1707728        NaN        NaN     85.6
# 11      319560        NaN        NaN    100.0
# 12  Compromiso        NaN        NaN      NaN
# 13      128131        NaN        NaN    100.0
# 14           0        NaN        NaN      0.0
# 15  Compromiso        NaN        NaN      NaN
# 16      262409        NaN        NaN     82.7
# 17      224693        NaN        NaN    100.0
# 18        4871        NaN        NaN    100.0
# 19       42750        NaN        NaN    100.0
# 20       75222        NaN        NaN    100.0
# 21  Compromiso        NaN        NaN      NaN
# 22        7404        NaN        NaN     96.1
# 23        7606        NaN        NaN    100.0
# 24      257598        NaN        NaN    100.0
# 25      266900        NaN        NaN     96.7
# 26      134863        NaN        NaN     86.6
# 27      144190        NaN        NaN    100.0
# 28       36779        NaN        NaN    100.0
# 29           0        NaN        NaN      0.0
# 30      123675        NaN        NaN     69.0
# 31  Compromiso        NaN        NaN      NaN
# 32           0        NaN        NaN      0.0
# 33      108325        NaN        NaN     86.2
# 34        5532        NaN        NaN     78.2
# 35           0        NaN        NaN      0.0
# 36        4791        NaN        NaN     79.2
# 37       82902        NaN        NaN     93.9
# 38  Compromiso        NaN        NaN      NaN
# 39      467778        NaN        NaN     94.7
# 40           0        NaN        NaN      0.0
# 41      410677        NaN        NaN     79.3
# 42      273735        NaN        NaN     92.7
# 43      465421        NaN        NaN     79.0
# 44       12396        NaN        NaN     52.4
# 45  Compromiso        NaN        NaN      NaN
# 46           0        NaN        NaN      0.0
# 47      303780        NaN        NaN     78.0
#
#                     Responsabilidad funcional  year  \
# 0                                        None  2007
# 1                                        None  2007
# 2                                        None  2007
# 3                                        None  2007
# 4                                        None  2007
# 5                                        None  2007
# 6                                        None  2007
# 7                                        None  2007
# 8   Función 03: ADMINISTRACION Y PLANEAMIENTO  2007
# 9   Función 03: ADMINISTRACION Y PLANEAMIENTO  2007
# 10  Función 03: ADMINISTRACION Y PLANEAMIENTO  2007
# 11  Función 03: ADMINISTRACION Y PLANEAMIENTO  2007
# 12                        Función 04: AGRARIA  2007
# 13                        Función 04: AGRARIA  2007
# 14                        Función 04: AGRARIA  2007
# 15            Función 09: EDUCACION Y CULTURA  2007
# 16            Función 09: EDUCACION Y CULTURA  2007
# 17            Función 09: EDUCACION Y CULTURA  2007
# 18            Función 09: EDUCACION Y CULTURA  2007
# 19            Función 09: EDUCACION Y CULTURA  2007
# 20            Función 09: EDUCACION Y CULTURA  2007
# 21  Función 05: PROTECCION Y PREVISION SOCIAL  2007
# 22  Función 05: PROTECCION Y PREVISION SOCIAL  2007
# 23  Función 05: PROTECCION Y PREVISION SOCIAL  2007
# 24  Función 05: PROTECCION Y PREVISION SOCIAL  2007
# 25  Función 05: PROTECCION Y PREVISION SOCIAL  2007
# 26  Función 05: PROTECCION Y PREVISION SOCIAL  2007
# 27  Función 05: PROTECCION Y PREVISION SOCIAL  2007
# 28  Función 05: PROTECCION Y PREVISION SOCIAL  2007
# 29  Función 05: PROTECCION Y PREVISION SOCIAL  2007
# 30  Función 05: PROTECCION Y PREVISION SOCIAL  2007
# 31            Función 14: SALUD Y SANEAMIENTO  2007
# 32            Función 14: SALUD Y SANEAMIENTO  2007
# 33            Función 14: SALUD Y SANEAMIENTO  2007
# 34            Función 14: SALUD Y SANEAMIENTO  2007
# 35            Función 14: SALUD Y SANEAMIENTO  2007
# 36            Función 14: SALUD Y SANEAMIENTO  2007
# 37            Función 14: SALUD Y SANEAMIENTO  2007
# 38                     Función 16: TRANSPORTE  2007
# 39                     Función 16: TRANSPORTE  2007
# 40                     Función 16: TRANSPORTE  2007
# 41                     Función 16: TRANSPORTE  2007
# 42                     Función 16: TRANSPORTE  2007
# 43                     Función 16: TRANSPORTE  2007
# 44                     Función 16: TRANSPORTE  2007
# 45   Función 17: VIVIENDA Y DESARROLLO URBANO  2007
# 46   Función 17: VIVIENDA Y DESARROLLO URBANO  2007
# 47   Función 17: VIVIENDA Y DESARROLLO URBANO  2007
#
#                                          source_file  \
# 0                             MPCT_FUNCION_2007.xlsx
# 1                             MPCT_FUNCION_2007.xlsx
# 2                             MPCT_FUNCION_2007.xlsx
# 3                             MPCT_FUNCION_2007.xlsx
# 4                             MPCT_FUNCION_2007.xlsx
# 5                             MPCT_FUNCION_2007.xlsx
# 6                             MPCT_FUNCION_2007.xlsx
# 7                             MPCT_FUNCION_2007.xlsx
# 8             MPCT_FUNCION_2007_admPlaneamiento.xlsx
# 9             MPCT_FUNCION_2007_admPlaneamiento.xlsx
# 10            MPCT_FUNCION_2007_admPlaneamiento.xlsx
# 11            MPCT_FUNCION_2007_admPlaneamiento.xlsx
# 12                    MPCT_FUNCION_2007_agraria.xlsx
# 13                    MPCT_FUNCION_2007_agraria.xlsx
# 14                    MPCT_FUNCION_2007_agraria.xlsx
# 15           MPCT_FUNCION_2007_educacionCultura.xlsx
# 16           MPCT_FUNCION_2007_educacionCultura.xlsx
# 17           MPCT_FUNCION_2007_educacionCultura.xlsx
# 18           MPCT_FUNCION_2007_educacionCultura.xlsx
# 19           MPCT_FUNCION_2007_educacionCultura.xlsx
# 20           MPCT_FUNCION_2007_educacionCultura.xlsx
# 21  MPCT_FUNCION_2007_proteccionPrevisionSocial.xlsx
# 22  MPCT_FUNCION_2007_proteccionPrevisionSocial.xlsx
# 23  MPCT_FUNCION_2007_proteccionPrevisionSocial.xlsx
# 24  MPCT_FUNCION_2007_proteccionPrevisionSocial.xlsx
# 25  MPCT_FUNCION_2007_proteccionPrevisionSocial.xlsx
# 26  MPCT_FUNCION_2007_proteccionPrevisionSocial.xlsx
# 27  MPCT_FUNCION_2007_proteccionPrevisionSocial.xlsx
# 28  MPCT_FUNCION_2007_proteccionPrevisionSocial.xlsx
# 29  MPCT_FUNCION_2007_proteccionPrevisionSocial.xlsx
# 30  MPCT_FUNCION_2007_proteccionPrevisionSocial.xlsx
# 31           MPCT_FUNCION_2007_saludSaneamiento.xlsx
# 32           MPCT_FUNCION_2007_saludSaneamiento.xlsx
# 33           MPCT_FUNCION_2007_saludSaneamiento.xlsx
# 34           MPCT_FUNCION_2007_saludSaneamiento.xlsx
# 35           MPCT_FUNCION_2007_saludSaneamiento.xlsx
# 36           MPCT_FUNCION_2007_saludSaneamiento.xlsx
# 37           MPCT_FUNCION_2007_saludSaneamiento.xlsx
# 38                 MPCT_FUNCION_2007_transporte.xlsx
# 39                 MPCT_FUNCION_2007_transporte.xlsx
# 40                 MPCT_FUNCION_2007_transporte.xlsx
# 41                 MPCT_FUNCION_2007_transporte.xlsx
# 42                 MPCT_FUNCION_2007_transporte.xlsx
# 43                 MPCT_FUNCION_2007_transporte.xlsx
# 44                 MPCT_FUNCION_2007_transporte.xlsx
# 45   MPCT_FUNCION_2007_viviendaDesarrollourbano.xlsx
# 46   MPCT_FUNCION_2007_viviendaDesarrollourbano.xlsx
# 47   MPCT_FUNCION_2007_viviendaDesarrollourbano.xlsx
#
#                                               Funcion Unnamed: 4 Unnamed: 5  \
# 0                                                 NaN  Devengado     Girado
# 1   03: PLANEAMIENTO, GESTIÓN Y RESERVA DE CONTING...    2161468    2103220
# 2                                    10: AGROPECUARIA     128131     124431
# 3                               23: PROTECCIÓN SOCIAL     979015     977247
# 4                                       22: EDUCACIÓN     609944     554999
# 5                                           20: SALUD     201549     197396
# 6                                      15: TRANSPORTE    1630006    1517590
# 7                    19: VIVIENDA Y DESARROLLO URBANO     303780     303119
# 8                                                 NaN  Devengado     Girado
# 9                                                 NaN     134179     134179
# 10                                                NaN    1707728    1650416
# 11                                                NaN     319560     318625
# 12                                                NaN  Devengado     Girado
# 13                                                NaN     128131     124431
# 14                                                NaN          0          0
# 15                                                NaN  Devengado     Girado
# 16                                                NaN     262409     246727
# 17                                                NaN     224693     219034
# 18                                                NaN       4871       4871
# 19                                                NaN      42750      29250
# 20                                                NaN      75222      55117
# 21                                                NaN  Devengado     Girado
# 22                                                NaN       7404       7404
# 23                                                NaN       7606       7606
# 24                                                NaN     257598     257598
# 25                                                NaN     266900     266900
# 26                                                NaN     134863     134330
# 27                                                NaN     144190     144190
# 28                                                NaN      36779      36779
# 29                                                NaN          0          0
# 30                                                NaN     123675     122440
# 31                                                NaN  Devengado     Girado
# 32                                                NaN          0          0
# 33                                                NaN     108325     105860
# 34                                                NaN       5532       5532
# 35                                                NaN          0          0
# 36                                                NaN       4791       4791
# 37                                                NaN      82902      81213
# 38                                                NaN  Devengado     Girado
# 39                                                NaN     467778     467752
# 40                                                NaN          0          0
# 41                                                NaN     410677     344207
# 42                                                NaN     273735     266435
# 43                                                NaN     465421     426801
# 44                                                NaN      12396      12396
# 45                                                NaN  Devengado     Girado
# 46                                                NaN          0          0
# 47                                                NaN     303780     303119
#
#                                    Actividad/Proyecto
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9          1000110: CONDUCCION Y ORIENTACION SUPERIOR
# 10                    1000267: GESTION ADMINISTRATIVA
# 11       2002632: CONSTRUCCION DE LOCALES MUNICIPALES
# 12                                                NaN
# 13        2000032: APOYO A LA PRODUCCION AGROPECUARIA
# 14          2005898: CONSTRUCCION DE SISTEMA DE RIEGO
# 15                                                NaN
# 16        2005230: CONSTRUCCION DE CENTROS EDUCATIVOS
# 17                  2005722: CONSTRUCCION DE ESTADIOS
# 18          2006326: CONSTRUCCION DE LOSAS DEPORTIVAS
# 19        2009708: EQUIPAMIENTO DE CENTROS EDUCATIVOS
# 20         2014600: MEJORAMIENTO DE PISCINAS PUBLICAS
# 21                                                NaN
# 22                1000347: OBLIGACIONES PREVISIONALES
# 23         1000541: APOYO AL CIUDADANO Y A LA FAMILIA
# 24                1000588: PROGRAMA DEL VASO DE LECHE
# 25  1014852: COMEDORES, ALIMENTOS POR TRABAJO, HOG...
# 26           2000028: APOYO A LA COMUNICACION COMUNAL
# 27                 2004528: CONSTRUCCION DE ALBERGUES
# 28         2006048: CONSTRUCCION DE LOCALES COMUNALES
# 29     2006222: CONSTRUCCION DE CASA DEL ADULTO MAYOR
# 30                 2006291: CONSTRUCCION DE COMEDORES
# 31                                                NaN
# 32                             2000437: REFORESTACION
# 33            2003232: AMPLIACION DE PUESTOS DE SALUD
# 34          2006226: CONSTRUCCION DE PUESTOS DE SALUD
# 35         2007558: CONSTRUCCION DE RELLENO SANITARIO
# 36  2007748: CONSTRUCCION DE SISTEMA DE ABASTECIMI...
# 37  2011547: MEJORAMIENTO DE SISTEMA DE ABASTECIMI...
# 38                                                NaN
# 39                  1000654: MANTENIMIENTO VIAL LOCAL
# 40       2005978: CONSTRUCCION DE TROCHAS CARROZABLES
# 41                   2007304: CONSTRUCCION DE PUENTES
# 42       2011461: MEJORAMIENTO DE TROCHAS CARROZABLES
# 43                   2012307: PAVIMENTACION DE CALLES
# 44        2013237: REHABILITACION DE PISTAS Y VEREDAS
# 45                                                NaN
# 46      2005153: CONSTRUCCION DE CEMENTERIO MUNICIPAL
# 47          2019354: RECONSTRUCCION DE PLAZA DE ARMAS

# %%
df_2007 = df_2007[['year', 'Responsabilidad funcional','Actividad/Proyecto', 'Funcion', 'source_file', 'PIA', 'PIM', 'Ejecución', 'Unnamed: 4', 'Unnamed: 5', 'Avance %']]
df_2007.head()
# Out:
#    year Responsabilidad funcional Actividad/Proyecto  \
# 0  2007                      None                NaN
# 1  2007                      None                NaN
# 2  2007                      None                NaN
# 3  2007                      None                NaN
# 4  2007                      None                NaN
#
#                                              Funcion             source_file  \
# 0                                                NaN  MPCT_FUNCION_2007.xlsx
# 1  03: PLANEAMIENTO, GESTIÓN Y RESERVA DE CONTING...  MPCT_FUNCION_2007.xlsx
# 2                                   10: AGROPECUARIA  MPCT_FUNCION_2007.xlsx
# 3                              23: PROTECCIÓN SOCIAL  MPCT_FUNCION_2007.xlsx
# 4                                      22: EDUCACIÓN  MPCT_FUNCION_2007.xlsx
#
#          PIA        PIM   Ejecución Unnamed: 4 Unnamed: 5 Avance %
# 0        NaN        NaN  Compromiso  Devengado     Girado      NaN
# 1  1819517.0  2449205.0     2161468    2161468    2103220     88.3
# 2   140000.0   128134.0      128131     128131     124431    100.0
# 3   594781.0  1064751.0      979015     979015     977247     91.9
# 4  1082528.0   664767.0      609944     609944     554999     91.8

# %%
df_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       48 non-null     int64
#  1   Responsabilidad funcional  40 non-null     object
#  2   Actividad/Proyecto         33 non-null     object
#  3   Funcion                    7 non-null      object
#  4   source_file                48 non-null     object
#  5   PIA                        40 non-null     float64
#  6   PIM                        40 non-null     float64
#  7   Ejecución                  48 non-null     object
#  8   Unnamed: 4                 48 non-null     object
#  9   Unnamed: 5                 48 non-null     object
#  10  Avance %                   40 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 4.3+ KB

# %%
df_2015 = load_spending_data_for_year(r"D:\cg_inter_stuff\Data_engineer\PipeLiningEverythingProjetcs\consultaAmigable_pipeline\dev\spending_data", 2015)


df_2015
# Out:
# Error reading ~$MPCT_FUNCION_2015_ambiente.xlsx: [Errno 13] Permission denied: 'D:\\cg_inter_stuff\\Data_engineer\\PipeLiningEverythingProjetcs\\consultaAmigable_pipeline\\dev\\spending_data\\SMPCT_2015\\~$MPCT_FUNCION_2015_ambiente.xlsx'
#                                               Funcion        PIA        PIM  \
# 0                                                 NaN        NaN        NaN
# 1   03: PLANEAMIENTO, GESTION Y RESERVA DE CONTING...  4045504.0  5862099.0
# 2                       05: ORDEN PUBLICO Y SEGURIDAD   317860.0   115146.0
# 3                                    10: AGROPECUARIA        0.0  2045223.0
# 4                                         12: ENERGIA        0.0    61369.0
# ..                                                ...        ...        ...
# 80                                                NaN        0.0   384604.0
# 81                                                NaN        0.0   143529.0
# 82                                                NaN        NaN        NaN
# 83                                                NaN        0.0      454.0
# 84                                                NaN        0.0   143075.0
#
#     Certificación  Compromiso Anual                       Ejecución  \
# 0             NaN               NaN  Atención de Compromiso Mensual
# 1       5025437.0         4992124.0                         4991071
# 2        101283.0          101283.0                          101283
# 3       1877232.0         1875578.0                         1875578
# 4         34722.0           34722.0                           34722
# ..            ...               ...                             ...
# 80       313520.0          270473.0                          270473
# 81       141346.0          140546.0                          140546
# 82            NaN               NaN  Atención de Compromiso Mensual
# 83            0.0               0.0                               0
# 84       141346.0          140546.0                          140546
#
#    Unnamed: 6 Unnamed: 7 Avance %                 Responsabilidad funcional  \
# 0   Devengado     Girado      NaN                                      None
# 1     4987126    4960832     85.1                                      None
# 2      101283     101283     88.0                                      None
# 3     1875178    1875178     91.7                                      None
# 4       34722      34722     56.6                                      None
# ..        ...        ...      ...                                       ...
# 80     270473     270473     70.3  Función 19: VIVIENDA Y DESARROLLO URBANO
# 81     140546     140546     97.9  Función 19: VIVIENDA Y DESARROLLO URBANO
# 82  Devengado     Girado      NaN  Función 19: VIVIENDA Y DESARROLLO URBANO
# 83          0          0      0.0  Función 19: VIVIENDA Y DESARROLLO URBANO
# 84     140546     140546     98.2  Función 19: VIVIENDA Y DESARROLLO URBANO
#
#     year                              function  \
# 0   2015                               general
# 1   2015                               general
# 2   2015                               general
# 3   2015                               general
# 4   2015                               general
# ..   ...                                   ...
# 80  2015              viviendadesarrollourbano
# 81  2015              viviendadesarrollourbano
# 82  2015  viviendadesarrollourbano_sinproducto
# 83  2015  viviendadesarrollourbano_sinproducto
# 84  2015  viviendadesarrollourbano_sinproducto
#
#                                           source_file  \
# 0                              MPCT_FUNCION_2015.xlsx
# 1                              MPCT_FUNCION_2015.xlsx
# 2                              MPCT_FUNCION_2015.xlsx
# 3                              MPCT_FUNCION_2015.xlsx
# 4                              MPCT_FUNCION_2015.xlsx
# ..                                                ...
# 80    MPCT_FUNCION_2015_viviendaDesarrolloUrbano.xlsx
# 81    MPCT_FUNCION_2015_viviendaDesarrolloUrbano.xlsx
# 82  MPCT_FUNCION_2015_viviendaDesarrolloUrbano_sin...
# 83  MPCT_FUNCION_2015_viviendaDesarrolloUrbano_sin...
# 84  MPCT_FUNCION_2015_viviendaDesarrolloUrbano_sin...
#
#                                   Producto / Proyecto  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 80  2272607: INSTALACION DE LA LOSA DEPORTIVA MULT...
# 81                              3999999: SIN PRODUCTO
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
#
#                Actividad / Acción de Inversión / Obra
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83  5000397: ACTUALIZACION Y ESTANDARIZACION DEL C...
# 84          5000462: APOYO AL DESARROLLO URBANO LOCAL
#
# [85 rows x 15 columns]

# %%
#df_2015 = df_2015[['year', 'Producto / Proyecto', 'Actividad / Acción de Inversión / Obra', 'function', 'Funcion', 'source_file', 'PIA', 'PIM', 'Ejecución', 'Unnamed: 6', 'Unnamed: 7', 'Avance %']]
#df_2015

# %%
df_2024 = load_spending_data_for_year(r"D:\cg_inter_stuff\Data_engineer\PipeLiningEverythingProjetcs\consultaAmigable_pipeline\dev\spending_data", 2024)


df_2024.head()
# Out:
# Error reading ~$MPCT_FUNCION_2024_agropecuario.xlsx: [Errno 13] Permission denied: 'D:\\cg_inter_stuff\\Data_engineer\\PipeLiningEverythingProjetcs\\consultaAmigable_pipeline\\dev\\spending_data\\SMPCT_2024\\~$MPCT_FUNCION_2024_agropecuario.xlsx'
# Error reading ~$MPCT_FUNCION_2024_previsionSocial_sinProducto.xlsx: [Errno 13] Permission denied: 'D:\\cg_inter_stuff\\Data_engineer\\PipeLiningEverythingProjetcs\\consultaAmigable_pipeline\\dev\\spending_data\\SMPCT_2024\\~$MPCT_FUNCION_2024_previsionSocial_sinProducto.xlsx'
#                                              Funcion         PIA         PIM  \
# 0                                                NaN         NaN         NaN
# 1  03: PLANEAMIENTO, GESTION Y RESERVA DE CONTING...  15458879.0  13876625.0
# 2                      05: ORDEN PUBLICO Y SEGURIDAD    406092.0    528536.0
# 3                                        07: TRABAJO    400000.0   1116240.0
# 4                                       08: COMERCIO         0.0     24500.0
#
#    Certificación  Compromiso Anual                       Ejecución Unnamed: 6  \
# 0            NaN               NaN  Atención de Compromiso Mensual  Devengado
# 1     13743625.0        13584571.0                        13578391   13535937
# 2       520263.0          519673.0                          519673     519673
# 3      1096783.0         1087356.0                         1087356    1051121
# 4        24500.0           24500.0                           22117      22117
#
#   Unnamed: 7 Avance % Responsabilidad funcional  year function  \
# 0     Girado      NaN                      None  2024  general
# 1   13513748     97.5                      None  2024  general
# 2     519673     98.3                      None  2024  general
# 3    1050841     94.2                      None  2024  general
# 4      22117     90.3                      None  2024  general
#
#               source_file Producto / Proyecto  \
# 0  MPCT_FUNCION_2024.xlsx                 NaN
# 1  MPCT_FUNCION_2024.xlsx                 NaN
# 2  MPCT_FUNCION_2024.xlsx                 NaN
# 3  MPCT_FUNCION_2024.xlsx                 NaN
# 4  MPCT_FUNCION_2024.xlsx                 NaN
#
#   Actividad / Acción de Inversión / Obra
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN

# %%
import pandas as pd
import re

def process_siaf_dataframe(df):
    """
    Takes a SIAF dataframe, identifies the column containing project descriptions,
    and extracts structured columns for a dimensional model.
    """
    
    # 1. Identify which column has the project text
    # We look for common names found in your raw tables
    target_cols = ['Producto / Proyecto', 'Funcion', 'Actividad/Proyecto', 'Actividad / Acción de Inversión / Obra']
    source_col = next((col for col in target_cols if col in df.columns), None)
    
    if not source_col:
        print("Warning: No project description column found.")
        return df

    def extract_details(text):
        if pd.isna(text) or text == "" or not any(char.isdigit() for char in str(text)[:7]):
            return pd.Series([None] * 7)
        
        text = str(text).strip()
        
        # A. Extract CUI (7 digits at the start)
        cui_match = re.search(r'^(\d{7})', text)
        cui = cui_match.group(1) if cui_match else None
        
        # Remove CUI and colon to clean the name
        clean_name = re.sub(r'^\d{7}\s*[:\-]\s*', '', text)
        
        # B. Extract Naturaleza (First word: INSTALACION, MEJORAMIENTO, etc.)
        naturaleza_match = re.search(r'^([A-ZÁÉÍÓÚÑ]+)', clean_name)
        naturaleza = naturaleza_match.group(1) if naturaleza_match else None
        
        # C. Extract Location (Sector/Neighborhood)
        # Usually starts after "EN EL/LA" or "DE LA" and ends before "DISTRITO"
        loc_match = re.search(r'(?:EN EL|EN LA|EN)\s+(.*?)(?=\s+DEL DISTRITO|\s+DISTRITO|\s+PROVINCIA|$)', clean_name, re.I)
        localidad = loc_match.group(1).strip() if loc_match else None
        
        # D. Extract District (DISTRITO DE ...)
        dist_match = re.search(r'DISTRITO DE\s+([\w\s]+?)(?=\s+PROVINCIA|\s+DEPARTAMENTO|\s+-|$)', clean_name, re.I)
        distrito = dist_match.group(1).strip() if dist_match else None
        
        # E. Extract Province (PROVINCIA DE ...)
        prov_match = re.search(r'PROVINCIA DE\s+([\w\s]+?)(?=\s+DEPARTAMENTO|\s+REGION|\s+-|$)', clean_name, re.I)
        provincia = prov_match.group(1).strip() if prov_match else None
        
        # F. Extract Departamento (Last part after the dash or keywords)
        # If there's a dash at the end, the last part is usually the Dept.
        parts = clean_name.split('-')
        departamento = parts[-1].strip() if len(parts) > 1 else None
        
        return pd.Series([cui, naturaleza, clean_name, localidad, distrito, provincia, departamento])

    # Apply extraction
    new_cols = ['cui', 'naturaleza', 'proyecto_nombre', 'localidad', 'distrito', 'provincia', 'departamento']
    df[new_cols] = df[source_col].apply(extract_details)
    
    # Optional: Filter out rows that didn't have a CUI (like total sum rows or headers)
    # df = df.dropna(subset=['cui'])
    
    return df

# Example Usage:
# df_cleaned = process_siaf_dataframe(your_raw_df)

# %%
df_2024=process_siaf_dataframe(df_2024)

# %%
df_2024.columns
# Out:
# Index(['Funcion', 'PIA', 'PIM', 'Certificación', 'Compromiso Anual',
#        'Ejecución', 'Unnamed: 6', 'Unnamed: 7', 'Avance %',
#        'Responsabilidad funcional', 'year', 'function', 'source_file',
#        'Producto / Proyecto', 'Actividad / Acción de Inversión / Obra', 'cui',
#        'naturaleza', 'proyecto_nombre', 'localidad', 'distrito', 'provincia',
#        'departamento'],
#       dtype='object')

# %%
df_2024
# Out:
#                                                Funcion         PIA  \
# 0                                                  NaN         NaN
# 1    03: PLANEAMIENTO, GESTION Y RESERVA DE CONTING...  15458879.0
# 2                        05: ORDEN PUBLICO Y SEGURIDAD    406092.0
# 3                                          07: TRABAJO    400000.0
# 4                                         08: COMERCIO         0.0
# ..                                                 ...         ...
# 192                                                NaN         0.0
# 193                                                NaN         0.0
# 194                                                NaN         0.0
# 195                                                NaN         0.0
# 196                                                NaN         0.0
#
#             PIM  Certificación  Compromiso Anual  \
# 0           NaN            NaN               NaN
# 1    13876625.0     13743625.0        13584571.0
# 2      528536.0       520263.0          519673.0
# 3     1116240.0      1096783.0         1087356.0
# 4       24500.0        24500.0           24500.0
# ..          ...            ...               ...
# 192     26071.0        26070.0           26070.0
# 193     13002.0        13001.0           13001.0
# 194   1000000.0       547645.0          542231.0
# 195    128301.0       128301.0          128301.0
# 196     94485.0        94484.0           94484.0
#
#                           Ejecución Unnamed: 6 Unnamed: 7 Avance %  \
# 0    Atención de Compromiso Mensual  Devengado     Girado      NaN
# 1                          13578391   13535937   13513748     97.5
# 2                            519673     519673     519673     98.3
# 3                           1087356    1051121    1050841     94.2
# 4                             22117      22117      22117     90.3
# ..                              ...        ...        ...      ...
# 192                           26070      26070      25970    100.0
# 193                           13001      13001      13001    100.0
# 194                          486651     486651     486651     48.7
# 195                          128301     128301     128136    100.0
# 196                           94484      94484      94484    100.0
#
#                     Responsabilidad funcional  ...  \
# 0                                        None  ...
# 1                                        None  ...
# 2                                        None  ...
# 3                                        None  ...
# 4                                        None  ...
# ..                                        ...  ...
# 192  Función 19: VIVIENDA Y DESARROLLO URBANO  ...
# 193  Función 19: VIVIENDA Y DESARROLLO URBANO  ...
# 194  Función 19: VIVIENDA Y DESARROLLO URBANO  ...
# 195  Función 19: VIVIENDA Y DESARROLLO URBANO  ...
# 196  Función 19: VIVIENDA Y DESARROLLO URBANO  ...
#
#                                          source_file  \
# 0                             MPCT_FUNCION_2024.xlsx
# 1                             MPCT_FUNCION_2024.xlsx
# 2                             MPCT_FUNCION_2024.xlsx
# 3                             MPCT_FUNCION_2024.xlsx
# 4                             MPCT_FUNCION_2024.xlsx
# ..                                               ...
# 192  MPCT_FUNCION_2024_viviendaDesarrolloUrbano.xlsx
# 193  MPCT_FUNCION_2024_viviendaDesarrolloUrbano.xlsx
# 194  MPCT_FUNCION_2024_viviendaDesarrolloUrbano.xlsx
# 195  MPCT_FUNCION_2024_viviendaDesarrolloUrbano.xlsx
# 196  MPCT_FUNCION_2024_viviendaDesarrolloUrbano.xlsx
#
#                                    Producto / Proyecto  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 192  2342967: CREACION DE LA PLAZA PRINCIPAL EN EL ...
# 193  2533719: MEJORAMIENTO DE LA PLAZA PRINCIAL DE ...
# 194  2548982: CREACION DE LA PLAZA PRINCIPAL DE LA ...
# 195  2617903: MEJORAMIENTO DEL SERVICIOS DE ESPACIO...
# 196  2656923: REMODELACION DE AREA VERDE; EN EL(LA)...
#
#     Actividad / Acción de Inversión / Obra      cui    naturaleza  \
# 0                                      NaN     None          None
# 1                                      NaN     None          None
# 2                                      NaN     None          None
# 3                                      NaN     None          None
# 4                                      NaN     None          None
# ..                                     ...      ...           ...
# 192                                    NaN  2342967      CREACION
# 193                                    NaN  2533719  MEJORAMIENTO
# 194                                    NaN  2548982      CREACION
# 195                                    NaN  2617903  MEJORAMIENTO
# 196                                    NaN  2656923  REMODELACION
#
#                                        proyecto_nombre  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 192  CREACION DE LA PLAZA PRINCIPAL EN EL CENTRO PO...
# 193  MEJORAMIENTO DE LA PLAZA PRINCIAL DE CARMEN AL...
# 194  CREACION DE LA PLAZA PRINCIPAL DE LA LOCALIDAD...
# 195  MEJORAMIENTO DEL SERVICIOS DE ESPACIOS PUBLICO...
# 196  REMODELACION DE AREA VERDE; EN EL(LA) PLAZA PR...
#
#                                              localidad          distrito  \
# 0                                                 None              None
# 1                                                 None              None
# 2                                                 None              None
# 3                                                 None              None
# 4                                                 None              None
# ..                                                 ...               ...
# 192             CENTRO POBLADO DE SAN JUAN DE LLAC-HUA              None
# 193                                               ALTO    CHALLHUAHUACHO
# 194                                               None    CHALLHUAHUACHO
# 195  PUENTE UNION DEL BARRIO PAMPAÑA DE CENTRO POBL...  TAMBOBAMBA DE LA
# 196                             EL(LA) PLAZA PRINCIPAL              None
#
#           provincia              departamento
# 0              None                      None
# 1              None                      None
# 2              None                      None
# 3              None                      None
# 4              None                      None
# ..              ...                       ...
# 192      COTABAMBAS                  APURIMAC
# 193      COTABAMBAS  DEPARTAMENTO DE APURIMAC
# 194      COTABAMBAS  DEPARTAMENTO DE APURIMAC
# 195  COTABAMBAS DEL                      None
# 196            None                      None
#
# [197 rows x 22 columns]

# %%
from pathlib import Path
import pandas as pd

def load_spending_data_separated(base_dir, year):
    base_dir = Path(base_dir)
    year_folder = base_dir / f"SMPCT_{year}"
    
    if not year_folder.exists():
        raise FileNotFoundError(f"Folder not found: {year_folder}")

    # To store the separate outputs
    general_df = pd.DataFrame()
    categorized_dfs = []

    for file in year_folder.glob("*.xlsx"):
        filename = file.stem 
        parts = filename.split("_")

        # Logic to identify the "General" file vs the others
        # MPCT_FUNCION_2015.xlsx has exactly 3 parts
        if len(parts) == 3:
            try:
                print(f"Processing General file: {file.name}")
                general_df = load_file_with_dynamic_header(file)
                general_df["year"] = int(year)
                general_df["function"] = "general"
                general_df["source_file"] = file.name
            except Exception as e:
                print(f"Error reading general file {file.name}: {e}")
        
        else:
            # These are the files like _salud, _educacion, _sinProducto, etc.
            try:
                df = load_file_with_dynamic_header(file)
                df["year"] = int(year)
                df["function"] = "_".join(parts[3:]).lower()
                df["source_file"] = file.name
                categorized_dfs.append(df)
            except Exception as e:
                print(f"Error reading categorized file {file.name}: {e}")

    # Combine all category files into one, keeping general separate
    all_categories_df = pd.concat(categorized_dfs, ignore_index=True) if categorized_dfs else pd.DataFrame()

    return general_df, all_categories_df

# Usage
# df_general, df_others = load_spending_data_separated('your_path', 2015)

# %%
df_2015 = load_spending_data_separated(r"D:\cg_inter_stuff\Data_engineer\PipeLiningEverythingProjetcs\consultaAmigable_pipeline\dev\spending_data", 2015)


print(df_2015)
# Out:
# Processing General file: MPCT_FUNCION_2015.xlsx
# Error reading categorized file ~$MPCT_FUNCION_2015_ambiente.xlsx: [Errno 13] Permission denied: 'D:\\cg_inter_stuff\\Data_engineer\\PipeLiningEverythingProjetcs\\consultaAmigable_pipeline\\dev\\spending_data\\SMPCT_2015\\~$MPCT_FUNCION_2015_ambiente.xlsx'
# (                                              Funcion        PIA        PIM  \
# 0                                                 NaN        NaN        NaN
# 1   03: PLANEAMIENTO, GESTION Y RESERVA DE CONTING...  4045504.0  5862099.0
# 2                       05: ORDEN PUBLICO Y SEGURIDAD   317860.0   115146.0
# 3                                    10: AGROPECUARIA        0.0  2045223.0
# 4                                         12: ENERGIA        0.0    61369.0
# 5                                      15: TRANSPORTE  1640661.0  3785197.0
# 6                                        17: AMBIENTE   136183.0   538693.0
# 7                                     18: SANEAMIENTO    10000.0  3115889.0
# 8                    19: VIVIENDA Y DESARROLLO URBANO        0.0   897068.0
# 9                                           20: SALUD   216841.0   173073.0
# 10                                      22: EDUCACION  1077874.0        0.0
# 11                              23: PROTECCION SOCIAL   745256.0   775683.0
# 12                               24: PREVISION SOCIAL     7497.0     7797.0
#
#     Certificación  Compromiso Anual                       Ejecución  \
# 0             NaN               NaN  Atención de Compromiso Mensual
# 1       5025437.0         4992124.0                         4991071
# 2        101283.0          101283.0                          101283
# 3       1877232.0         1875578.0                         1875578
# 4         34722.0           34722.0                           34722
# 5       3094169.0         3072047.0                         3057431
# 6        458120.0          458059.0                          458059
# 7       2920305.0         2905021.0                         2905021
# 8        779617.0          735770.0                          735770
# 9         15030.0           15030.0                           15030
# 10            0.0               0.0                               0
# 11       731321.0          717661.0                          717261
# 12         7796.0            7796.0                            7796
#
#    Unnamed: 6 Unnamed: 7 Avance % Responsabilidad funcional  year function  \
# 0   Devengado     Girado      NaN                      None  2015  general
# 1     4987126    4960832     85.1                      None  2015  general
# 2      101283     101283     88.0                      None  2015  general
# 3     1875178    1875178     91.7                      None  2015  general
# 4       34722      34722     56.6                      None  2015  general
# 5     3056931    3027257     80.8                      None  2015  general
# 6      458059     457969     85.0                      None  2015  general
# 7     2905021    2904981     93.2                      None  2015  general
# 8      735770     735700     82.0                      None  2015  general
# 9       15030      15030      8.7                      None  2015  general
# 10          0          0      0.0                      None  2015  general
# 11     715689     711816     92.3                      None  2015  general
# 12       7796       7796    100.0                      None  2015  general
#
#                source_file
# 0   MPCT_FUNCION_2015.xlsx
# 1   MPCT_FUNCION_2015.xlsx
# 2   MPCT_FUNCION_2015.xlsx
# 3   MPCT_FUNCION_2015.xlsx
# 4   MPCT_FUNCION_2015.xlsx
# 5   MPCT_FUNCION_2015.xlsx
# 6   MPCT_FUNCION_2015.xlsx
# 7   MPCT_FUNCION_2015.xlsx
# 8   MPCT_FUNCION_2015.xlsx
# 9   MPCT_FUNCION_2015.xlsx
# 10  MPCT_FUNCION_2015.xlsx
# 11  MPCT_FUNCION_2015.xlsx
# 12  MPCT_FUNCION_2015.xlsx  ,                                   Producto / Proyecto  PIA        PIM  \
# 0                                                 NaN  NaN        NaN
# 1   2123183: CONSTRUCCION DEL SISTEMA DE RIEGO EN ...  0.0    47121.0
# 2   2180865: INSTALACION DEL SISTEMA DE RIEGO POR ...  0.0  1917347.0
# 3   2289480: MEJORAMIENTO Y PROMOCION DE LA ARTICU...  0.0    80755.0
# 4                                                 NaN  NaN        NaN
# ..                                                ...  ...        ...
# 67  2272607: INSTALACION DE LA LOSA DEPORTIVA MULT...  0.0   384604.0
# 68                              3999999: SIN PRODUCTO  0.0   143529.0
# 69                                                NaN  NaN        NaN
# 70                                                NaN  0.0      454.0
# 71                                                NaN  0.0   143075.0
#
#     Certificación  Compromiso Anual                       Ejecución  \
# 0             NaN               NaN  Atención de Compromiso Mensual
# 1         10139.0           10139.0                           10139
# 2       1788248.0         1786594.0                         1786594
# 3         78845.0           78845.0                           78845
# 4             NaN               NaN  Atención de Compromiso Mensual
# ..            ...               ...                             ...
# 67       313520.0          270473.0                          270473
# 68       141346.0          140546.0                          140546
# 69            NaN               NaN  Atención de Compromiso Mensual
# 70            0.0               0.0                               0
# 71       141346.0          140546.0                          140546
#
#    Unnamed: 6 Unnamed: 7 Avance %                 Responsabilidad funcional  \
# 0   Devengado     Girado      NaN                  Función 10: AGROPECUARIA
# 1       10139      10139     21.5                  Función 10: AGROPECUARIA
# 2     1786594    1786594     93.2                  Función 10: AGROPECUARIA
# 3       78445      78445     97.1                  Función 10: AGROPECUARIA
# 4   Devengado     Girado      NaN                      Función 17: AMBIENTE
# ..        ...        ...      ...                                       ...
# 67     270473     270473     70.3  Función 19: VIVIENDA Y DESARROLLO URBANO
# 68     140546     140546     97.9  Función 19: VIVIENDA Y DESARROLLO URBANO
# 69  Devengado     Girado      NaN  Función 19: VIVIENDA Y DESARROLLO URBANO
# 70          0          0      0.0  Función 19: VIVIENDA Y DESARROLLO URBANO
# 71     140546     140546     98.2  Función 19: VIVIENDA Y DESARROLLO URBANO
#
#     year                              function  \
# 0   2015                          agropecuario
# 1   2015                          agropecuario
# 2   2015                          agropecuario
# 3   2015                          agropecuario
# 4   2015                              ambiente
# ..   ...                                   ...
# 67  2015              viviendadesarrollourbano
# 68  2015              viviendadesarrollourbano
# 69  2015  viviendadesarrollourbano_sinproducto
# 70  2015  viviendadesarrollourbano_sinproducto
# 71  2015  viviendadesarrollourbano_sinproducto
#
#                                           source_file  \
# 0                 MPCT_FUNCION_2015_agropecuario.xlsx
# 1                 MPCT_FUNCION_2015_agropecuario.xlsx
# 2                 MPCT_FUNCION_2015_agropecuario.xlsx
# 3                 MPCT_FUNCION_2015_agropecuario.xlsx
# 4                     MPCT_FUNCION_2015_ambiente.xlsx
# ..                                                ...
# 67    MPCT_FUNCION_2015_viviendaDesarrolloUrbano.xlsx
# 68    MPCT_FUNCION_2015_viviendaDesarrolloUrbano.xlsx
# 69  MPCT_FUNCION_2015_viviendaDesarrolloUrbano_sin...
# 70  MPCT_FUNCION_2015_viviendaDesarrolloUrbano_sin...
# 71  MPCT_FUNCION_2015_viviendaDesarrolloUrbano_sin...
#
#                Actividad / Acción de Inversión / Obra
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70  5000397: ACTUALIZACION Y ESTANDARIZACION DEL C...
# 71          5000462: APOYO AL DESARROLLO URBANO LOCAL
#
# [72 rows x 14 columns])
