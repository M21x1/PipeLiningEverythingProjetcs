# %%
import sqlite3
import pandas as pd
import ast
import numpy as np

# %% [markdown]
# This file will show a discovery phase/process used before creating `data_cleanser.py` file which automates the cleaning and updates processes.

# %% [markdown]
# # Connecting SQLite3 Database
#
# First I'll connect to the database to determine which tables are contained in the database.

# %%
#con = sqlite3.connect('cademycode.db')
con = sqlite3.connect('cademycode_updated.db')
cur = con.cursor()

# We'll read all table names
table_list = [a for a in cur.execute("SELECT name FROM sqlite_master WHERE type='table';")] # .fetchall()
print(table_list)
# Out:
# [('cademycode_students',), ('cademycode_courses',), ('cademycode_student_jobs',)]

# %% [markdown]
# # Extract tables from db file
#
# I'll extract the tables using simple query statements and save them to python variables.

# %%
students = pd.read_sql_query("SELECT * from cademycode_students", con)
career_paths = pd.read_sql_query("SELECT * from cademycode_courses", con)
students_jobs = pd.read_sql_query("SELECT * from cademycode_student_jobs", con)

# %%
print('students:', len(students))
print('career_paths:', len(career_paths))
print('students_jobs:', len(students_jobs))
# Out:
# students: 6000
# career_paths: 10
# students_jobs: 13

# %% [markdown]
# # Working with the `Students` table
#
# Let's work with the students file first since it is the largest. I'll start by taking a look at the first few rows of data to get a general sense of what the structure looks like.

# %%
students.head()
# Out:
#    uuid             name         dob sex  \
# 0     1  Annabelle Avery  1943-07-03   F
# 1     2      Micah Rubio  1991-02-07   M
# 2     3       Hosea Dale  1989-12-07   M
# 3     4     Mariann Kirk  1988-07-31   F
# 4     5  Lucio Alexander  1963-08-31   M
#
#                                         contact_info job_id num_course_taken  \
# 0  {"mailing_address": "303 N Timber Key, Irondal...    7.0              6.0
# 1  {"mailing_address": "767 Crescent Fair, Shoals...    7.0              5.0
# 2  {"mailing_address": "P.O. Box 41269, St. Bonav...    7.0              8.0
# 3  {"mailing_address": "517 SE Wintergreen Isle, ...    6.0              7.0
# 4  {"mailing_address": "18 Cinder Cliff, Doyles b...    7.0             14.0
#
#   current_career_path_id time_spent_hrs
# 0                    1.0           4.99
# 1                    8.0            4.4
# 2                    8.0           6.74
# 3                    9.0          12.31
# 4                    3.0           5.64

# %% [markdown]
# Next I'll examine the datatypes of each column and check for any null values using the `.info()` funtion.

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    6000 non-null   int64
#  1   name                    6000 non-null   object
#  2   dob                     6000 non-null   object
#  3   sex                     6000 non-null   object
#  4   contact_info            6000 non-null   object
#  5   job_id                  5986 non-null   object
#  6   num_course_taken        5733 non-null   object
#  7   current_career_path_id  5513 non-null   object
#  8   time_spent_hrs          5513 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 422.0+ KB

# %% [markdown]
# A couple things I notice when examining the DataFrame so far:
# * `contact_info` appears to be a dictionary, which will require additional work to explode it into separate columns
# * Each row has a UUID, which means one student can only be one row
# * `dob` seems to be date of birth, will want to make sure it is a datetime object
#     * Calculating age from DoB might be useful as a grouping column
# * None of the numerical columns are coming in as floats or integers
#     * `job_id` and `current_career_path_id` should be treated as categorical data since they are IDs
# * It looks like there is missing data in `job_id`, `num_course_taken`, `current_career_path_id`

# %% [markdown]
# # Calculating approximate age
#
# I'll convert `dob` into approximate age. This provides a couple benefits over a datetime field:
#
# * To an analytics team who's trying to tell a story with numbers, age makes more aesthetic sense.
# * This creates a new ordinal or even categorical field for analysts to dive into.

# %%
now = pd.to_datetime('now')
#students['age'] = (now - pd.to_datetime(students['dob'])).astype('<m8[Y]') # deprecated because years are not all the same length
#students['age'] = (now - pd.to_datetime(students['dob']))/pd.Timedelta(days=365.25) # not exact but close enough

# Accurate age calculation
dob = pd.to_datetime(students['dob'])
students['age'] = (now.year - dob.dt.year) - (
    (now.month < dob.dt.month) | ((now.month == dob.dt.month) & (now.day < dob.dt.day))
)

students['age_group'] = np.int64((students['age']/10))*10

# %%
# Accurate age calculation
dob = pd.to_datetime(students['dob'])
students['age'] = (now.year - dob.dt.year) - (
    (now.month < dob.dt.month) | ((now.month == dob.dt.month) & (now.day < dob.dt.day))
)

# %%
students.head()
# Out:
#    uuid             name         dob sex  \
# 0     1  Annabelle Avery  1943-07-03   F
# 1     2      Micah Rubio  1991-02-07   M
# 2     3       Hosea Dale  1989-12-07   M
# 3     4     Mariann Kirk  1988-07-31   F
# 4     5  Lucio Alexander  1963-08-31   M
#
#                                         contact_info job_id num_course_taken  \
# 0  {"mailing_address": "303 N Timber Key, Irondal...    7.0              6.0
# 1  {"mailing_address": "767 Crescent Fair, Shoals...    7.0              5.0
# 2  {"mailing_address": "P.O. Box 41269, St. Bonav...    7.0              8.0
# 3  {"mailing_address": "517 SE Wintergreen Isle, ...    6.0              7.0
# 4  {"mailing_address": "18 Cinder Cliff, Doyles b...    7.0             14.0
#
#   current_career_path_id time_spent_hrs  age  age_group
# 0                    1.0           4.99   82         80
# 1                    8.0            4.4   34         30
# 2                    8.0           6.74   35         30
# 3                    9.0          12.31   37         30
# 4                    3.0           5.64   62         60

# %% [markdown]
# ## Explode the dictionary

# %%
explode_contact = pd.json_normalize(students['contact_info'])
explode_contact.dtypes
# Out:
# Series([], dtype: object)

# %% [markdown]
# Interestingly enough, pandas imported the `contact_info` column as a string type rather than as JSON. This adds an extra step and requires me to convert the strings to dictionaries, and then explode:

# %%
students['contact_info'] = students['contact_info'].apply(lambda x: ast.literal_eval(x))
explode_contact = pd.json_normalize(students['contact_info'])
students = pd.concat([students.drop(columns=['contact_info']), explode_contact], axis=1)

# %%
students.head()
# Out:
#    uuid             name         dob sex job_id num_course_taken  \
# 0     1  Annabelle Avery  1943-07-03   F    7.0              6.0
# 1     2      Micah Rubio  1991-02-07   M    7.0              5.0
# 2     3       Hosea Dale  1989-12-07   M    7.0              8.0
# 3     4     Mariann Kirk  1988-07-31   F    6.0              7.0
# 4     5  Lucio Alexander  1963-08-31   M    7.0             14.0
#
#   current_career_path_id time_spent_hrs  age  age_group  \
# 0                    1.0           4.99   82         80
# 1                    8.0            4.4   34         30
# 2                    8.0           6.74   35         30
# 3                    9.0          12.31   37         30
# 4                    3.0           5.64   62         60
#
#                                      mailing_address  \
# 0       303 N Timber Key, Irondale, Wisconsin, 84736
# 1          767 Crescent Fair, Shoals, Indiana, 37439
# 2   P.O. Box 41269, St. Bonaventure, Virginia, 83637
# 3     517 SE Wintergreen Isle, Lane, Arkansas, 82242
# 4  18 Cinder Cliff, Doyles borough, Rhode Island,...
#
#                             email
# 0  annabelle_avery9376@woohoo.com
# 1             rubio6772@hmail.com
# 2     hosea_dale8084@coldmail.com
# 3              kirk4005@hmail.com
# 4         alexander9810@hmail.com

# %% [markdown]
# After exploding the dictionary column, it could be worth spliting the `mailing_address` column into `street`, `city`, `state`, `zip_code` columns.

# %%
split_address = students.mailing_address.str.split(',', expand=True)
split_address.columns = ['street', 'city', 'state', 'zip_code']
students = pd.concat([students.drop('mailing_address', axis=1), split_address], axis=1)
students.head()
# Out:
#    uuid             name         dob sex job_id num_course_taken  \
# 0     1  Annabelle Avery  1943-07-03   F    7.0              6.0
# 1     2      Micah Rubio  1991-02-07   M    7.0              5.0
# 2     3       Hosea Dale  1989-12-07   M    7.0              8.0
# 3     4     Mariann Kirk  1988-07-31   F    6.0              7.0
# 4     5  Lucio Alexander  1963-08-31   M    7.0             14.0
#
#   current_career_path_id time_spent_hrs  age  age_group  \
# 0                    1.0           4.99   82         80
# 1                    8.0            4.4   34         30
# 2                    8.0           6.74   35         30
# 3                    9.0          12.31   37         30
# 4                    3.0           5.64   62         60
#
#                             email                   street              city  \
# 0  annabelle_avery9376@woohoo.com         303 N Timber Key          Irondale
# 1             rubio6772@hmail.com        767 Crescent Fair            Shoals
# 2     hosea_dale8084@coldmail.com           P.O. Box 41269   St. Bonaventure
# 3              kirk4005@hmail.com  517 SE Wintergreen Isle              Lane
# 4         alexander9810@hmail.com          18 Cinder Cliff    Doyles borough
#
#            state zip_code
# 0      Wisconsin    84736
# 1        Indiana    37439
# 2       Virginia    83637
# 3       Arkansas    82242
# 4   Rhode Island    73737

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    6000 non-null   int64
#  1   name                    6000 non-null   object
#  2   dob                     6000 non-null   object
#  3   sex                     6000 non-null   object
#  4   job_id                  5986 non-null   object
#  5   num_course_taken        5733 non-null   object
#  6   current_career_path_id  5513 non-null   object
#  7   time_spent_hrs          5513 non-null   object
#  8   age                     6000 non-null   int32
#  9   age_group               6000 non-null   int64
#  10  email                   6000 non-null   object
#  11  street                  6000 non-null   object
#  12  city                    6000 non-null   object
#  13  state                   6000 non-null   object
#  14  zip_code                6000 non-null   object
# dtypes: int32(1), int64(2), object(12)
# memory usage: 679.8+ KB

# %% [markdown]
# ## Fixing column datatypes
#
# Let's fix the column datatypes first. I know that `num_course_taken` should be integers and `time_spent_hrs` should be floats. Even though `job_id` and `current_career_path_id` look numerical, they should be treated as categorical data since they are IDs. Due to null values, I can't cast `job_id` and `current_career_path_id` into integers, so I'll cast them as floats for now.

# %%
students['job_id'] = students['job_id'].astype(float)
students['current_career_path_id'] = students['current_career_path_id'].astype(float)
students['num_course_taken'] = students['num_course_taken'].astype(float)
students['time_spent_hrs'] = students['time_spent_hrs'].astype(float)
students['age'] = students['age'].astype(float)

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    6000 non-null   int64
#  1   name                    6000 non-null   object
#  2   dob                     6000 non-null   object
#  3   sex                     6000 non-null   object
#  4   job_id                  5986 non-null   float64
#  5   num_course_taken        5733 non-null   float64
#  6   current_career_path_id  5513 non-null   float64
#  7   time_spent_hrs          5513 non-null   float64
#  8   age                     6000 non-null   float64
#  9   age_group               6000 non-null   int64
#  10  email                   6000 non-null   object
#  11  street                  6000 non-null   object
#  12  city                    6000 non-null   object
#  13  state                   6000 non-null   object
#  14  zip_code                6000 non-null   object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 703.3+ KB

# %% [markdown]
# ## Handling Missing Data
#
# `num_course_taken`
#
# Let's examine the missing data to determine if the missing data is missing at random, structurally missing, or missing not at random:

# %%
missing_course_taken = students[students[['num_course_taken']].isnull().any(axis=1)]
display(missing_course_taken)
# Out:
#       uuid              name         dob sex  job_id  num_course_taken  \
# 25      26     Doug Browning  1970-06-08   M     7.0               NaN
# 26      27   Damon Schrauwen  1953-10-31   M     4.0               NaN
# 51      52        Alisa Neil  1977-05-28   F     5.0               NaN
# 70      71   Chauncey Hooper  1962-04-07   M     3.0               NaN
# 80      81   Ellyn van Heest  1984-06-28   F     3.0               NaN
# ...    ...               ...         ...  ..     ...               ...
# 5978  5979   Long Sonneveldt  1942-09-26   M     5.0               NaN
# 5979  5980   Lucio Blackwell  1942-05-16   M     7.0               NaN
# 5980  5981    Jonell Gilmore  1942-08-29   F     9.0               NaN
# 5981  5982  Genevieve Mercer  1975-04-01   F     7.0               NaN
# 5993  5994      Rod Creelman  1993-04-10   M     9.0               NaN
#
#       current_career_path_id  time_spent_hrs   age  age_group  \
# 25                       5.0            1.92  55.0         50
# 26                      10.0            3.73  72.0         70
# 51                       8.0           22.86  48.0         40
# 70                       3.0            3.97  63.0         60
# 80                      10.0           12.39  41.0         40
# ...                      ...             ...   ...        ...
# 5978                     4.0           14.21  83.0         80
# 5979                     3.0           19.87  83.0         80
# 5980                    10.0           25.02  83.0         80
# 5981                     3.0            3.78  50.0         50
# 5993                     4.0           17.43  32.0         30
#
#                              email                  street              city  \
# 25             doug7761@inlook.com          P.O. Box 15845            Devine
# 26            damon9864@woohoo.com          P.O. Box 84659             Maben
# 51            alisa9616@inlook.com           16 View Annex            Mosses
# 70         chauncey6352@woohoo.com           955 Dewy Flat    Slaughterville
# 80    ellyn_vanheest8375@hmail.com         872 Cider Glade           Chicken
# ...                            ...                     ...               ...
# 5978           long7531@woohoo.com        961 Crystal Ramp         Rice Lake
# 5979      blackwell6843@inlook.com     655 Grand Pond Port   Lostant village
# 5980          jonell5887@hmail.com  660 Golden Pond Square   San Carlos Park
# 5981      genevieve8331@woohoo.com         475 Bluff Annex      East Griffin
# 5993       creelman5073@inlook.com        945 Burning Oval    Radium Springs
#
#                 state zip_code
# 25            Florida    23097
# 26            Georgia    66137
# 51       North Dakota    25748
# 70     South Carolina    22167
# 80           Delaware    42689
# ...               ...      ...
# 5978          Georgia    40747
# 5979          Arizona    28358
# 5980          Indiana    21002
# 5981             Utah    16744
# 5993       New Mexico    46204
#
# [267 rows x 15 columns]

# %% [markdown]
# Let's take a look at the distribution of missing and complete data grouped by the categorical data. If the distribution between the missing and non-missing data is similar, we can conclude that the data is MAR if no identifiable pattern is found. Generally, if something is MNAR or structurally missing, it should be visible by graphing the data.

# %%
sg = (students.groupby('sex').count()['uuid']/len(students)).rename('complete')
mg = (missing_course_taken.groupby('sex').count()['uuid']/len(missing_course_taken)).rename('incomplete')
df = pd.concat([sg, mg], axis=1)
df.plot.bar()
# Out:
# <Axes: xlabel='sex'>

# %%
sg = (students.groupby('job_id').count()['uuid']/len(students)).rename('complete')
mg = (missing_course_taken.groupby('job_id').count()['uuid']/len(missing_course_taken)).rename('incomplete')
df = pd.concat([sg, mg], axis=1)
df.plot.bar()
# Out:
# <Axes: xlabel='job_id'>

# %%
sg = (students.groupby('age_group').count()['uuid']/len(students)).rename('complete')
mg = (missing_course_taken.groupby('age_group').count()['uuid']/len(missing_course_taken)).rename('incomplete')
df = pd.concat([sg, mg], axis=1)
df.plot.bar()
# Out:
# <Axes: xlabel='age_group'>

# %% [markdown]
# Nothing looks out of the ordinary in terms of distribution or from a simple eye-test. Addionally, there are instances of zeroes in the column, so we can conclude that the NaN's aren't just students who haven't enrolled in a course yet - ruling out structural missing data.
#
# I think it's safe to call this missing at random (MAR). Since less than 5% of the data is missing anb it appears to be MAR, I can remove the missing data with little impact. Instead of completely deleting it, I will store the missing data in a separate table in the event that my analytics teams wants to try to fill it in.

# %%
missing_data = pd.DataFrame()
missing_data = pd.concat([missing_data, missing_course_taken])
students = students.dropna(subset=['num_course_taken'])

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5733 entries, 0 to 5999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    5733 non-null   int64
#  1   name                    5733 non-null   object
#  2   dob                     5733 non-null   object
#  3   sex                     5733 non-null   object
#  4   job_id                  5720 non-null   float64
#  5   num_course_taken        5733 non-null   float64
#  6   current_career_path_id  5267 non-null   float64
#  7   time_spent_hrs          5267 non-null   float64
#  8   age                     5733 non-null   float64
#  9   age_group               5733 non-null   int64
#  10  email                   5733 non-null   object
#  11  street                  5733 non-null   object
#  12  city                    5733 non-null   object
#  13  state                   5733 non-null   object
#  14  zip_code                5733 non-null   object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 716.6+ KB

# %% [markdown]
# ### `job_id`

# %% [markdown]
# Since this missing data is categorical, we can't impute the data. If this data is MAR, there are only a few other options:
#
# * Delete the data due to the very low percentage of affect rows
# * Replace with the most frequent category
# * Develop a classification model to predict the missing category

# %%
missing_job_id = students[students[['job_id']].isnull().any(axis=1)]
missing_job_id.head()
# Out:
#       uuid              name         dob sex  job_id  num_course_taken  \
# 162    163        Glen Riley  2002-08-22   M     NaN               8.0
# 757    758  Mercedez Vorberg  2002-03-25   F     NaN              15.0
# 854    855           Kurt Ho  2002-05-29   M     NaN               0.0
# 1029  1030      Penny Gaines  2002-03-01   N     NaN              15.0
# 1542  1543  Frederick Reilly  2002-11-13   M     NaN               7.0
#
#       current_career_path_id  time_spent_hrs   age  age_group  \
# 162                      3.0            5.70  23.0         20
# 757                      4.0            4.14  23.0         20
# 854                      8.0           23.72  23.0         20
# 1029                     4.0           16.25  23.0         20
# 1542                     9.0           21.32  23.0         20
#
#                                 email             street               city  \
# 162          glen_riley4484@hmail.com     P.O. Box 37267    Cornlea village
# 757           mercedez6297@woohoo.com  284 Cedar Seventh     Virden village
# 854                 ho6107@inlook.com     P.O. Box 27254               Olin
# 1029             gaines2897@hmail.com     138 Misty Vale   Stockton borough
# 1542  frederick_reilly6971@woohoo.com     P.O. Box 40769      Quakervillage
#
#                state zip_code
# 162        Tennessee    19192
# 757       Washington    60489
# 854    New Hampshire    60067
# 1029   West Virginia    53630
# 1542        Maryland    96218

# %% [markdown]
# With only 5 rows of missing data and no pattern that I can deduce, this data also appears to be MAR. Taking into account both the amount of resources (time) I have and the impact that fixing 5 rows of data will have, the most reasonable action is to delete this data as well.

# %%
missing_data = pd.concat([missing_data, missing_job_id])
students = students.dropna(subset=['job_id'])

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5720 entries, 0 to 5999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    5720 non-null   int64
#  1   name                    5720 non-null   object
#  2   dob                     5720 non-null   object
#  3   sex                     5720 non-null   object
#  4   job_id                  5720 non-null   float64
#  5   num_course_taken        5720 non-null   float64
#  6   current_career_path_id  5254 non-null   float64
#  7   time_spent_hrs          5254 non-null   float64
#  8   age                     5720 non-null   float64
#  9   age_group               5720 non-null   int64
#  10  email                   5720 non-null   object
#  11  street                  5720 non-null   object
#  12  city                    5720 non-null   object
#  13  state                   5720 non-null   object
#  14  zip_code                5720 non-null   object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 715.0+ KB

# %% [markdown]
# ### `current_career_path_id`
#
# `current_career_path_id` is also categorical, so we can apply the same conclusions to the missing data if we can conclude that this is also MAR.

# %%
missing_path_id = students[students[['current_career_path_id']].isnull().any(axis=1)]

# %%
missing_path_id.head()
# Out:
#     uuid                   name         dob sex  job_id  num_course_taken  \
# 15    16          Norene Dalton  1976-04-30   F     6.0               0.0
# 19    20  Sofia van Steenbergen  1990-02-21   N     7.0              13.0
# 30    31      Christoper Warner  1989-12-28   M     2.0               5.0
# 49    50           Antony Horne  1996-05-29   M     3.0               2.0
# 54    55              Omar Bunk  1955-11-08   M     3.0              14.0
#
#     current_career_path_id  time_spent_hrs   age  age_group  \
# 15                     NaN             NaN  49.0         40
# 19                     NaN             NaN  35.0         30
# 30                     NaN             NaN  35.0         30
# 49                     NaN             NaN  29.0         20
# 54                     NaN             NaN  70.0         70
#
#                             email               street              city  \
# 15    norene_dalton9509@hmail.com    130 Wishing Essex            Branch
# 19  vansteenbergen8482@inlook.com  634 Clear Barn Dell            Beaman
# 30        warner5906@coldmail.com  556 Stony Highlands             Drain
# 49         antony577@coldmail.com       P.O. Box 78685             Lenox
# 54          omar1245@coldmail.com      445 Dale Hollow   Vermont village
#
#               state zip_code
# 15             Ohio    13616
# 19          Georgia    33288
# 30         Illinois    01973
# 49            Texas    15516
# 54   South Carolina    28329

# %% [markdown]
# The most interesting thing to note is that `time_spent_hrs` is also missing with the first 5 rows of missing `current_career_path_id`. This is worth investigating further because it's possible that `current_career_path_id` and `time_spent_hrs` are structurally missing - the student is not currently taking any classes.

# %%
missing_path_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 466 entries, 15 to 5569
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    466 non-null    int64
#  1   name                    466 non-null    object
#  2   dob                     466 non-null    object
#  3   sex                     466 non-null    object
#  4   job_id                  466 non-null    float64
#  5   num_course_taken        466 non-null    float64
#  6   current_career_path_id  0 non-null      float64
#  7   time_spent_hrs          0 non-null      float64
#  8   age                     466 non-null    float64
#  9   age_group               466 non-null    int64
#  10  email                   466 non-null    object
#  11  street                  466 non-null    object
#  12  city                    466 non-null    object
#  13  state                   466 non-null    object
#  14  zip_code                466 non-null    object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 58.2+ KB

# %% [markdown]
# As hypothesized, it seems that `time_spent_hrs` is null wherever `current_career_path_id` is too. This would mean that both are structurally missing. To resolve this, I will set `current_career_path_id` to a new id that will indicate no current career path, and I will set `time_spent_hrs` to 0 to indicate no hours spent.

# %%
students['current_career_path_id'].unique()
# Out:
# array([ 1.,  8.,  9.,  3.,  6., 10.,  5., nan,  4.,  7.,  2.])

# %%
students['current_career_path_id'] = np.where(students['current_career_path_id'].isnull(), 0, students['current_career_path_id'])
students['time_spent_hrs'] = np.where(students['time_spent_hrs'].isnull(), 0, students['time_spent_hrs'])

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5720 entries, 0 to 5999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    5720 non-null   int64
#  1   name                    5720 non-null   object
#  2   dob                     5720 non-null   object
#  3   sex                     5720 non-null   object
#  4   job_id                  5720 non-null   float64
#  5   num_course_taken        5720 non-null   float64
#  6   current_career_path_id  5720 non-null   float64
#  7   time_spent_hrs          5720 non-null   float64
#  8   age                     5720 non-null   float64
#  9   age_group               5720 non-null   int64
#  10  email                   5720 non-null   object
#  11  street                  5720 non-null   object
#  12  city                    5720 non-null   object
#  13  state                   5720 non-null   object
#  14  zip_code                5720 non-null   object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 715.0+ KB

# %% [markdown]
# ### Working with `career_paths` table

# %%
display(career_paths)
# Out:
#    career_path_id           career_path_name  hours_to_complete
# 0               1             data scientist                 20
# 1               2              data engineer                 20
# 2               3               data analyst                 12
# 3               4       software engineering                 25
# 4               5           backend engineer                 18
# 5               6          frontend engineer                 20
# 6               7              iOS developer                 27
# 7               8          android developer                 27
# 8               9  machine learning engineer                 35
# 9              10             ux/ui designer                 15

# %%
career_paths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   career_path_id     10 non-null     int64
#  1   career_path_name   10 non-null     object
#  2   hours_to_complete  10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %% [markdown]
# This table is relatively small compared to the `students` table. Taking a look at the full table, and sanity checking with the `.info()` function shows that this table doesn't require much. However, since we added in a new `career_path_id` to account for students who are not taking a career path, we need to add this to the database.

# %%
not_applicable = {'career_path_id': 0,
                  'career_path_name': 'not applicable',
                  'hours_to_complete': 0}

career_paths.loc[len(career_paths)] = not_applicable
display(career_paths)
# Out:
#     career_path_id           career_path_name  hours_to_complete
# 0                1             data scientist                 20
# 1                2              data engineer                 20
# 2                3               data analyst                 12
# 3                4       software engineering                 25
# 4                5           backend engineer                 18
# 5                6          frontend engineer                 20
# 6                7              iOS developer                 27
# 7                8          android developer                 27
# 8                9  machine learning engineer                 35
# 9               10             ux/ui designer                 15
# 10               0             not applicable                  0

# %% [markdown]
# # Working with `student_jobs` table

# %%
display(students_jobs)
# Out:
#     job_id        job_category  avg_salary
# 0        1           analytics       86000
# 1        2            engineer      101000
# 2        3  software developer      110000
# 3        4            creative       66000
# 4        5  financial services      135000
# 5        6           education       61000
# 6        7                  HR       80000
# 7        8             student       10000
# 8        9          healthcare      120000
# 9        0               other       80000
# 10       3  software developer      110000
# 11       4            creative       66000
# 12       5  financial services      135000

# %%
students_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_id        13 non-null     int64
#  1   job_category  13 non-null     object
#  2   avg_salary    13 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 444.0+ bytes

# %% [markdown]
# Similar to the `cademycode_courses` table, the `cademycode_student_jobs` table is small compared to the students table. Taking a look at the full table, and sanity checking with the `.info()` function shows that there are duplicates in this table based off of the `job_id` column. This is the only issue that needs to be addressed based off the inspection.

# %%
students_jobs.drop_duplicates(inplace=True)
display(students_jobs)
# Out:
#    job_id        job_category  avg_salary
# 0       1           analytics       86000
# 1       2            engineer      101000
# 2       3  software developer      110000
# 3       4            creative       66000
# 4       5  financial services      135000
# 5       6           education       61000
# 6       7                  HR       80000
# 7       8             student       10000
# 8       9          healthcare      120000
# 9       0               other       80000

# %% [markdown]
# # Joining tables

# %% [markdown]
# Before we begin joining - let's convert the ids to integers now that the null values have been resolved.

# %%
students['job_id'] = students['job_id'].astype(int)
students['current_career_path_id'] = students['current_career_path_id'].astype(int)

# %% [markdown]
# Now we can join them together:

# %%
final_df = students.merge(career_paths, left_on='current_career_path_id', right_on='career_path_id', how='left')
final_df = final_df.merge(students_jobs, on='job_id', how='left')
final_df.head()
# Out:
#    uuid             name         dob sex  job_id  num_course_taken  \
# 0     1  Annabelle Avery  1943-07-03   F       7               6.0
# 1     2      Micah Rubio  1991-02-07   M       7               5.0
# 2     3       Hosea Dale  1989-12-07   M       7               8.0
# 3     4     Mariann Kirk  1988-07-31   F       6               7.0
# 4     5  Lucio Alexander  1963-08-31   M       7              14.0
#
#    current_career_path_id  time_spent_hrs   age  age_group  \
# 0                       1            4.99  82.0         80
# 1                       8            4.40  34.0         30
# 2                       8            6.74  35.0         30
# 3                       9           12.31  37.0         30
# 4                       3            5.64  62.0         60
#
#                             email                   street              city  \
# 0  annabelle_avery9376@woohoo.com         303 N Timber Key          Irondale
# 1             rubio6772@hmail.com        767 Crescent Fair            Shoals
# 2     hosea_dale8084@coldmail.com           P.O. Box 41269   St. Bonaventure
# 3              kirk4005@hmail.com  517 SE Wintergreen Isle              Lane
# 4         alexander9810@hmail.com          18 Cinder Cliff    Doyles borough
#
#            state zip_code  career_path_id           career_path_name  \
# 0      Wisconsin    84736               1             data scientist
# 1        Indiana    37439               8          android developer
# 2       Virginia    83637               8          android developer
# 3       Arkansas    82242               9  machine learning engineer
# 4   Rhode Island    73737               3               data analyst
#
#    hours_to_complete job_category  avg_salary
# 0                 20           HR       80000
# 1                 27           HR       80000
# 2                 27           HR       80000
# 3                 35    education       61000
# 4                 12           HR       80000

# %%
final_df.info()
con.close()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5720 entries, 0 to 5719
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    5720 non-null   int64
#  1   name                    5720 non-null   object
#  2   dob                     5720 non-null   object
#  3   sex                     5720 non-null   object
#  4   job_id                  5720 non-null   int64
#  5   num_course_taken        5720 non-null   float64
#  6   current_career_path_id  5720 non-null   int64
#  7   time_spent_hrs          5720 non-null   float64
#  8   age                     5720 non-null   float64
#  9   age_group               5720 non-null   int64
#  10  email                   5720 non-null   object
#  11  street                  5720 non-null   object
#  12  city                    5720 non-null   object
#  13  state                   5720 non-null   object
#  14  zip_code                5720 non-null   object
#  15  career_path_id          5720 non-null   int64
#  16  career_path_name        5720 non-null   object
#  17  hours_to_complete       5720 non-null   int64
#  18  job_category            5720 non-null   object
#  19  avg_salary              5720 non-null   int64
# dtypes: float64(3), int64(7), object(10)
# memory usage: 893.9+ KB

# %% [markdown]
# ## Upsert cleansed and missing data tables to a new SQLite DB

# %%
sqlite_connection = sqlite3.connect('cademycode_cleansed.db')
final_df.to_sql('cademycode_aggregated', sqlite_connection, if_exists='replace', index=False)
# Out:
# 5720

# %%
db_df = pd.read_sql_query("SELECT * from cademycode_aggregated", sqlite_connection)

# %%
db_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5720 entries, 0 to 5719
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    5720 non-null   int64
#  1   name                    5720 non-null   object
#  2   dob                     5720 non-null   object
#  3   sex                     5720 non-null   object
#  4   job_id                  5720 non-null   int64
#  5   num_course_taken        5720 non-null   float64
#  6   current_career_path_id  5720 non-null   int64
#  7   time_spent_hrs          5720 non-null   float64
#  8   age                     5720 non-null   float64
#  9   age_group               5720 non-null   int64
#  10  email                   5720 non-null   object
#  11  street                  5720 non-null   object
#  12  city                    5720 non-null   object
#  13  state                   5720 non-null   object
#  14  zip_code                5720 non-null   object
#  15  career_path_id          5720 non-null   int64
#  16  career_path_name        5720 non-null   object
#  17  hours_to_complete       5720 non-null   int64
#  18  job_category            5720 non-null   object
#  19  avg_salary              5720 non-null   int64
# dtypes: float64(3), int64(7), object(10)
# memory usage: 893.9+ KB

# %%
missing_data.to_sql('incomplete_data', sqlite_connection, if_exists='replace', index=False)
# Out:
# 280

# %%
missing_df = pd.read_sql_query("SELECT * from incomplete_data", sqlite_connection)
sqlite_connection.close()

# %%
db_df.to_csv('cademycode_cleansed.csv')
